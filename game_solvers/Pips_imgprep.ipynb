# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('../data/pips.png')
img = img[1:]
img = img[776:814, 670:744]
img = np.concatenate((img[:, :7], img[:, 6:]), axis=1)
img = np.concatenate((img[:20], img[21:]), axis=0)
img = np.concatenate((img[:29], img[:8][::-1]), axis=0)
print(img.shape)

plt.imshow(img)
# Out:
# (37, 75, 4)

# %%
domino_base = np.copy(img)
domino_base[5:32, 6:33] = 246/255
domino_base[5:32, -33:-6] = 246/255
mpimg.imsave('../data/domino_base.png', domino_base)
plt.imshow(mpimg.imread('../data/domino_base.png'))

# %%
domino_4 = img[5:32, 6:33]
mpimg.imsave('../data/domino_4.png', domino_4)
plt.imshow(mpimg.imread('../data/domino_4.png'))

# %%
domino_2 = img[5:32, -33:-6]
mpimg.imsave('../data/domino_2.png', domino_2)
plt.imshow(mpimg.imread('../data/domino_2.png'))

# %%
img = mpimg.imread('../data/pips.png')
img = img[1:, :, :3]
img = img[776:814, 922:996]
img = np.concatenate((img[:, :7], img[:, 6:]), axis=1)
img = np.concatenate((img[:20], img[21:]), axis=0)
img = np.concatenate((img[:29], img[:8][::-1]), axis=0)
print(img.shape)

plt.imshow(img)
# Out:
# (37, 75, 3)

# %%
domino_5 = img[5:32, 6:33]
mpimg.imsave('../data/domino_5.png', domino_5)
plt.imshow(mpimg.imread('../data/domino_5.png'))

# %%
domino_6 = img[5:32, -33:-6]
mpimg.imsave('../data/domino_6.png', domino_6)
plt.imshow(mpimg.imread('../data/domino_6.png'))

# %%
img = mpimg.imread('../data/pips.png')
img = img[1:, :, :3]
img = img[822:860, 922:996]
img = np.concatenate((img[:, :7], img[:, 6:]), axis=1)
img = np.concatenate((img[:20], img[21:]), axis=0)
img = np.concatenate((img[:29], img[:8][::-1]), axis=0)
print(img.shape)

plt.imshow(img)
# Out:
# (37, 75, 3)

# %%
domino_3 = img[5:32, 6:33]
mpimg.imsave('../data/domino_3.png', domino_3)
plt.imshow(mpimg.imread('../data/domino_3.png'))

# %%
img = mpimg.imread('../data/pips.png')
img = img[1:, :, :3]
img = img[868:906, 880:954]
img = np.concatenate((img[:, :7], img[:, 6:]), axis=1)
img = np.concatenate((img[:20], img[21:]), axis=0)
img = np.concatenate((img[:29], img[:8][::-1]), axis=0)
print(img.shape)

plt.imshow(img)
# Out:
# (37, 75, 3)

# %%
domino_1 = img[5:32, 6:33]
mpimg.imsave('../data/domino_1.png', domino_1)
plt.imshow(mpimg.imread('../data/domino_1.png'))

# %%
domino_0 = img[5:32, -33:-6]
mpimg.imsave('../data/domino_0.png', domino_0)
plt.imshow(mpimg.imread('../data/domino_0.png'))
